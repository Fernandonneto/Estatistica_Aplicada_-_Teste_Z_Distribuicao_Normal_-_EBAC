# %% [markdown]
# # **MÓDULO 19**
# # Exercício: Estatística Aplicada

# %% [markdown]
# **Efetividade de Duas Estratégias de Ensino**
#
# Imagine que uma escola esteja avaliando a eficácia de duas estratégias de ensino de matemática para alunos do ensino médio. Eles querem determinar se há uma diferença significativa no desempenho médio dos alunos entre as duas estratégias.

# %% [markdown]
# # **Hipóteses:**
#
# * Hipótese nula (H0): A média das notas dos alunos na estratégia A é igual à média das notas dos alunos na estratégia B.
# * Hipótese alternativa (H1): A média das notas na Estratégia B é maior do que a média das notas na Estratégia A.

# %% [markdown]
# # **Dados:**
#
# * Amostra da Estratégia A: Notas de 50 alunos que receberam a Estratégia A.
# * Amostra da Estratégia B: Notas de 50 alunos que receberam a Estratégia B.

# %% [markdown]
# Usaremos um teste Z para comparar as médias das notas entre as duas amostras.

# %% [markdown]
# Se o p-valor do teste Z for menor que um nível de significância pré-determinado (por exemplo, α = 0.05), rejeitamos a hipótese nula e concluímos que há uma diferença significativa nas médias das notas entre as duas estratégias de ensino.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Os dados são criados a seguir:

# %%
# Definindo médias e desvios padrão para as notas nas duas estratégias
media_estrategia_A = 70
desvio_padrao_estrategia_A = 10

media_estrategia_B = 75
desvio_padrao_estrategia_B = 12

# Gerando as amostras de notas para cada estratégia de ensino da nossa base
np.random.seed(0)  # Para garantir a reprodutibilidade dos resultados
amostra_estrategia_A = np.random.normal(loc=media_estrategia_A, scale=desvio_padrao_estrategia_A, size=50)
amostra_estrategia_B = np.random.normal(loc=media_estrategia_B, scale=desvio_padrao_estrategia_B, size=50)

print("Notas da Estratégia A:", amostra_estrategia_A[:5])
print("Notas da Estratégia B:", amostra_estrategia_B[:5])
# Out:
# Notas da Estratégia A: [87.64052346 74.00157208 79.78737984 92.40893199 88.6755799 ]
# Notas da Estratégia B: [64.25440127 79.64282997 68.87033835 60.83241379 74.66181326]

# %% [markdown]
# # 1) De acordo com as informações analisadas o nosso teste é unilateral á direita, esquerda ou bicaudal? Justifique.

# %%
# Sua justificativa aqui

# %% [markdown]
# Teste unilateral à direita. Como a hipótese alternativa (H1) busca verificar se a média da `Estrátegia B` é maior que a da `Estrátegia A`, o teste estatístico adequado é unilateral á direita.

# %% [markdown]
# # 2) Calcule as médias para as duas amostragens e as variâncias. Quais insights você pode retirar comparando os dados?

# %%
#Seu código aqui
# Médias de cada estratégia
media_amostra_A = np.mean(amostra_estrategia_A)
media_amostra_B = np.mean(amostra_estrategia_B)
# Variâncias amostrais de cada estratégia
variancia_amostra_A = np.var(amostra_estrategia_A, ddof=1)
variancia_amostra_B = np.var(amostra_estrategia_B, ddof=1)

# Impressão dos resultados com formatação para padrão brasileiro (vírgula decimal)
print(f'Média da amostra A: {media_amostra_A:.2f}'.replace('.', ','))
print(f'Média da amostra B: {media_amostra_B:.2f}'.replace('.', ','))
print(f'\nVariância da amostra A: {variancia_amostra_A:.2f}'.replace('.', ','))
print(f'Variância da amostra B: {variancia_amostra_B:.2f}'.replace('.', ','))
# Out:
# Média da amostra A: 71,41
# Média da amostra B: 74,75
#
# Variância da amostra A: 129,27
# Variância da amostra B: 110,47

# %% [markdown]
# A diferença entre as médias indica que a amostra B apresenta um desempenho superior à amostra A, com um ganho de 3,34 pontos. Além disso, a menor variância da amostra B (diferença de -18,8 em relação à A) sugere maior consistência nos resultados, com menor dispersão das notas. Em conjunto, esses fatores indicam que a `Estratégia B` não apenas apresenta melhor desempenho médio, mas também maior estabilidade nos resultados.

# %% [markdown]
# # 3) Imprima os resultados da estatística do teste Z, p value e indique se rejeitaremos ou não a hipótese nula. Justifique sua resposta.

# %%
#Seu código aqui
# Tamanho das amostras
n = len(amostra_estrategia_B)

# Calcular a estatística de teste Z com a formula:
z_statistic = (media_amostra_B - media_amostra_A) / (((variancia_amostra_A/n) + (variancia_amostra_B/n))**0.5)

# Calcular o p-valor (teste unilateral à direita)
p_valor = 1 - stats.norm.cdf(z_statistic)

# Imprimir os resultados
print("Estatística de teste Z:", z_statistic)
print("p-valor:", p_valor)

# Comparar o p-valor com o nível de significância
nivel_significancia = 0.05
if p_valor < nivel_significancia:
    print("Rejeitamos a hipótese nula: há evidências estatísticas de que a Estratégia B apresenta desempenho superior à Estratégia A.")
else:
    print("Não rejeitamos a hipótese nula: não há evidências estatísticas suficientes para afirmar que a Estratégia B apresenta desempenho superior à Estratégia A.")
# Out:
# Estatística de teste Z: 1.5267455833477102
# p-valor: 0.06341214386181693
# Não rejeitamos a hipótese nula: não há evidências estatísticas suficientes para afirmar que a Estratégia B apresenta desempenho superior à Estratégia A.

# %% [markdown]
# O p-valor obtido (0,0634) é superior ao nível de significância adotado (α = 0,05), indicando que a probabilidade de observar a diferença entre as médias por acaso não é suficientemente baixa. Dessa forma, não se rejeita a hipótese nula, concluindo que não há evidências estatísticas suficientes para afirmar que a `Estratégia B` apresenta desempenho superior à  `Estratégia A`.

# %% [markdown]
# # 4) Para finalizar monte o gráfico da distribuição da estatística do nosso teste Z e explique o que pode ser observado através dele.

# %%
#Seu código aqu
# Configurações do gráfico
fig, ax = plt.subplots(figsize=(10, 5))

# Valores de X e Y para plotar a distribuição
x = np.linspace(-3, 3, 1000)
# x = np.linspace(-3, 3, 1000): Esta linha cria um array x de 1000 pontos igualmente espaçados no intervalo de -3 a 3. Esse intervalo foi escolhido para abranger uma ampla gama de valores típicos para a estatística de teste Z, que segue uma distribuição normal padrão
y = stats.norm.pdf(x, 0, 1)
# y = stats.norm.pdf(x, 0, 1): Esta linha calcula os valores de densidade de probabilidade para cada ponto no array x com base na distribuição normal padrão.

# Plotando a distribuição normal padrão
ax.plot(x, y, label='Distribuição Normal Padrão')

# Marcação do valor observado da estatística do teste
ax.vlines(x=[z_statistic], ymin=0, ymax=stats.norm.pdf(z_statistic, 0, 1),
          colors='r', linestyles='dotted', label='Valor observado da estatística de teste')

# Área crítica
critical_region = stats.norm.ppf(0.95)
ax.fill_between(x, y, where=(x > critical_region), color='gray', alpha=0.3, label='Área crítica')

# Legenda e rótulos
plt.legend()
plt.xlabel('Valor da Estatística de Teste Z')
plt.ylabel('Densidade')
plt.title('Distribuição da Estatística de Teste Z')
plt.grid(True)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# Por se tratar de um teste unilateral à direita, a região crítica está concentrada no extremo direito da distribuição. Nota-se que a estatística de teste encontra-se fora dessa região de rejeição, indicando que o valor observado não é suficientemente extremo para rejeitar a hipótese nula. Esse resultado é consistente com o p-valor superior ao nível de significância, reforçando que não há evidências estatísticas suficientes para afirmar que a `Estratégia B` apresenta desempenho superior à `Estratégia A`.
